# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from copy import deepcopy
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('lstm/dataset.txt', header=None, delimiter='\t')
ecg = df.iloc[:,2].values
ecg = ecg.reshape(len(ecg),-1)
print('len of ECG data : ',len(ecg))

scaler = StandardScaler()
std_ecg = scaler.fit_transform(ecg)

plt.style.use('ggplot')
plt.figure(figsize=(15,5))
plt.xlabel('time')
plt.ylabel('ecg\'s value')
plt.plot(np.arange(5000),std_ecg[:5000],color='b')
plt.ylim(-3,3)
x=np.arange(4200,4200)
y1=[-3]*len(x)
y2 = [3]*len(x)
plt.fill_between(x,y1,y2,facecolor='g', alpha=.3)
plt.show()
# Out:
# len of ECG data :  45000

# %%
normal_cycle=std_ecg[5000:]

plt.figure(figsize=(10,5))
plt.title('training data')
plt.xlabel('time')
plt.ylabel('ECG value')
plt.plot(np.arange(5000,8000),normal_cycle[:3000],color='b')
plt.show()
